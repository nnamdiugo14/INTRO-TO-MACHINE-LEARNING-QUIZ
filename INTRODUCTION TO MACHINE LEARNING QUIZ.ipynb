# %%
import pandas as pd

# %%
food_data1 = pd.read_csv('food data.csv', encoding='latin-1')

# %%
food_data1
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
food_data1.groupby('Item')['Y2014','Y2016'].sum()
# Out:
# <ipython-input-42-e45304dbb5c9>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   food_data1.groupby('Item')['Y2014','Y2016'].sum()
#                          Y2014      Y2016
# Item
# Alcohol, Non-Food      2403.00    2223.00
# Alcoholic Beverages  102410.11   96958.75
# Animal Products       11935.65   11661.69
# Animal fats          209460.54  183314.22
# Apples and products    9499.23    9853.26
# ...                        ...        ...
# Vegetables, Other    155038.96  156218.90
# Vegetal Products     107145.19  106792.72
# Wheat and products   232670.13  239377.07
# Wine                   4497.36    3872.09
# Yams                 200396.96  220626.20
#
# [119 rows x 2 columns]

# %%
food_data1['Y2015'].mean()
# Out:
# 135.23596649549236

# %%
food_data1['Y2015'].std()
# Out:
# 1603.4039839423301

# %%
food_data1['Y2016'].isnull().sum()
# Out:
# 1535

# %%
food_data1['Y2016'].isnull().sum()/food_data1['Y2016'].sum()
# Out:
# 0.0001892148135624223

# %%
food_data1.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
food_data1.groupby('Element')['Y2014','Y2016','Y2015','Y2017','Y2018'].sum()
# Out:
# <ipython-input-43-32e844b03ceb>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   food_data1.groupby('Element')['Y2014','Y2016','Y2015','Y2017','Y2018'].sum()
#                                              Y2014       Y2016       Y2015  \
# Element
# Domestic supply quantity                1996716.35  2044842.70  2021493.55
# Export Quantity                          150020.64   151920.46   157614.47
# Fat supply quantity (g/capita/day)        10225.56    10102.77    10235.74
# Feed                                     216927.89   228958.65   225050.22
# Food                                    1212332.49  1247022.17  1232361.10
# Food supply (kcal/capita/day)            454257.00   451810.00   453383.00
# Food supply quantity (kg/capita/yr)       49650.63    48985.28    49345.13
# Import Quantity                          274144.48   286582.78   267018.46
# ...

# %%
food_data1.groupby('Element')['Y2014'].sum()
# Out:
# Element
# Domestic supply quantity                  1996716.35
# Export Quantity                            150020.64
# Fat supply quantity (g/capita/day)          10225.56
# Feed                                       216927.89
# Food                                      1212332.49
# Food supply (kcal/capita/day)              454257.00
# Food supply quantity (kg/capita/yr)         49650.63
# Import Quantity                            274144.48
# Losses                                     153223.00
# Other uses (non-food)                       78718.13
# Processing                                 282923.00
# Production                                1931287.75
# Protein supply quantity (g/capita/day)      11836.46
# Residuals                                   30149.00
# Seed                                        21922.92
# Stock Variation                             58749.83
# Total Population - Both sexes             1031585.00
# Tourist consumption                           416.00
# ...

# %%
food_data1.groupby('Element')['Y2018'].sum()
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell

# %%
InteractiveShell.ast_node_interactivity = 'all'

# %%
food_data1[(food_data1['Element']== 'Import Quantity') & (food_data1['Area'] =='Algeria')].sum()
# Out:
# Area Code                                                     448
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                                  301030
# Item            Cereals - Excluding BeerWheat and productsRice...
# Element Code                                               628432
# Element         Import QuantityImport QuantityImport QuantityI...
# Unit            1000 tonnes1000 tonnes1000 tonnes1000 tonnes10...
# Y2014                                                     34940.1
# Y2015                                                     37841.9
# Y2016                                                     36736.1
# Y2017                                                     36059.3
# Y2018                                                     36238.3
# dtype: object

# %%
food_data1['Area'].describe()
# Out:
# count     60943
# unique       49
# top       Kenya
# freq       1560
# Name: Area, dtype: object
